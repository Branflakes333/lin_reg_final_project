# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import BayesianRidge
from sklearn.metrics import mean_squared_error, r2_score

# %%
# Get data
df = pd.read_csv("data/cleaned_data.csv")
df.head(5)
# Out:
#          date location_key  new_persons_vaccinated  \
# 0  2021-06-23        US_TX                 26724.0
# 1  2021-04-20        US_TX                     0.0
# 2  2021-04-20        US_TX                     0.0
# 3  2021-04-20        US_TX                     0.0
# 4  2021-03-03        US_TX                115051.0
#
#    cumulative_persons_vaccinated  new_confirmed  mobility_workplaces
# 0                     13760302.0           -6.0                -29.0
# 1                     10245431.0            4.0                -24.0
# 2                     10245431.0            4.0                -30.0
# 3                     10245431.0            4.0                -19.0
# 4                      3850248.0           40.0                 -8.0

# %%
X = df[['new_persons_vaccinated', 'cumulative_persons_vaccinated', 'mobility_workplaces']]
y = df['new_confirmed']

model = BayesianRidge()
model.fit(X, y)
# Out:
# BayesianRidge()

# %%
# Coefficients for each feature in the order of X columns
print("Coefficients:", model.coef_)

# Intercept term
print("Intercept:", model.intercept_)
# Out:
# Coefficients: [ 2.34642583e-04 -2.27165137e-06 -1.65283493e-06]
# Intercept: 24.052709502225937

# %%
# Evaluate model 
mse = mean_squared_error(y, y_pred)
r2 = r2_score(y, y_pred)

print("Mean Squared Error:", mse)
print("R^2 Score:", r2)

n = X.shape[0]  # number of samples
p = X.shape[1]  # number of predictors

adjusted_r2 = 1 - (1 - r2) * (n - 1) / (n - p - 1)

print("Adjusted R²:", adjusted_r2)
# Out:
# Mean Squared Error: 79.6661233908753
# R^2 Score: 0.7431815759109941
# Adjusted R²: 0.4863631518219882
